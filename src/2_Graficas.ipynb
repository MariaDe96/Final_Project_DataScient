# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import seaborn as sns

# %%
df = pd.read_csv('/workspaces/Final_Project_DataScient/data/processed/datafinal.csv')
df
# Out:
#         HHADULT  SEXVAR  MEDCOST1  SLEPTIM1  CVDSTRK3  ADDEPEV3  DIABETE4  \
# 0             2     1.0       0.0       6.0       0.0       1.0       0.0
# 1             4     1.0       0.0       7.0       0.0       0.0       0.0
# 2             2     1.0       0.0       7.0       0.0       0.0       0.0
# 3             2     0.0       0.0       6.0       0.0       0.0       3.0
# 4             2     0.0       0.0       5.0       0.0       0.0       0.0
# ...         ...     ...       ...       ...       ...       ...       ...
# 109974        1     0.0       0.0       6.0       0.0       0.0       0.0
# 109975        4     0.0       0.0       7.0       1.0       0.0       3.0
# 109976        2     1.0       0.0       7.0       0.0       0.0       0.0
# 109977        1     1.0       1.0       5.0       0.0       0.0       0.0
# 109978        2     0.0       0.0       5.0       0.0       0.0       0.0
#
#         MARITAL  RENTHOM1  VETERAN3  ...  _ASTHMS1  _DRDXAR2  _AGEG5YR  \
# ...

# %%
columnas = df.columns
columnas
for col in columnas:
    df = df[df[col] != -1]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77373 entries, 0 to 109978
# Data columns (total 39 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   HHADULT      77373 non-null  int64
#  1   SEXVAR       77373 non-null  float64
#  2   MEDCOST1     77373 non-null  float64
#  3   SLEPTIM1     77373 non-null  float64
#  4   CVDSTRK3     77373 non-null  float64
#  5   ADDEPEV3     77373 non-null  float64
#  6   DIABETE4     77373 non-null  float64
#  7   MARITAL      77373 non-null  float64
#  8   RENTHOM1     77373 non-null  float64
#  9   VETERAN3     77373 non-null  float64
#  10  EMPLOY1      77373 non-null  float64
#  11  DECIDE       77373 non-null  float64
#  12  DIFFALON     77373 non-null  float64
#  13  COLNCNCR     77373 non-null  float64
#  14  HIVRISK5     77373 non-null  float64
#  15  COVIDPOS     77373 non-null  float64
#  16  LSATISFY     77373 non-null  float64
#  17  EMTSUPRT     77373 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['HHADULT', 'SEXVAR', 'MEDCOST1', 'SLEPTIM1', 'CVDSTRK3', 'ADDEPEV3',
#        'DIABETE4', 'MARITAL', 'RENTHOM1', 'VETERAN3', 'EMPLOY1', 'DECIDE',
#        'DIFFALON', 'COLNCNCR', 'HIVRISK5', 'COVIDPOS', 'LSATISFY', 'EMTSUPRT',
#        'SDHISOLT', 'SDHEMPLY', 'SDHFOOD1', 'SDHBILLS', 'SDHUTILS', 'SDHTRNSP',
#        '_PHYS14D', '_MENT14D', '_HLTHPLN', '_TOTINDA', '_MICHD', '_ASTHMS1',
#        '_DRDXAR2', '_AGEG5YR', '_BMI5CAT', '_CHLDCNT', '_EDUCAG', '_INCOMG1',
#        '_RFBING6', '_AIDTST4', 'tobacco_use'],
#       dtype='object')

# %% [markdown]
# # 📊 Análisis Gráfico de Variables – Relación con Depresión (`ADDEPEV3`)
#
# Este apartado presenta un análisis exploratorio visual de las variables más relevantes del conjunto de datos, con especial enfoque en su relación con la variable objetivo `ADDEPEV3`.
#
# ---
#
# ### 🎯 Variable objetivo:
# - `ADDEPEV3`: ¿Alguna vez un médico u otro profesional le ha dicho que padece depresión?
#   - 1: Sí
#   - 0: No
#
# ---
#
# ## 🔍 Metodología del análisis
#
# ### 🟦 Variables categóricas
#
# Para cada variable categórica se generan tres visualizaciones:
#
# 1. **Distribución general (`countplot`)**
#    Frecuencia de cada categoría en la variable analizada.
#
# 2. **Correlación con `ADDEPEV3` (`heatmap`)**
#    Mide la asociación lineal entre la variable categórica (codificada numéricamente) y la variable objetivo.
#    ⚠️ *Nota: La correlación puede ser limitada en variables no ordinales.*
#
# 3. **Distribución condicional (`countplot` con `hue`)**
#    Permite visualizar cómo se distribuye `ADDEPEV3` en cada categoría de la variable.
#
# ### 🟨 Variables numéricas
#
# Para las variables numéricas, el análisis visual incluye:
#
# 1. **Distribución general (`histplot`)**
#    Muestra cómo se distribuyen los valores en la variable.
#
# 2. **Distribución y presencia de valores atípicos (`boxplot`)**
#    Permite detectar asimetrías y outliers.
#
# 3. **Correlación con `ADDEPEV3` (`heatmap`)**
#    Indica la fuerza y dirección de la relación lineal con la variable objetivo.
#
# ---
#
# ### 🧾 Análisis cualitativo
#
# Junto a cada bloque de gráficos se incluye una descripción que abarca:
#
# - El significado de la variable y su codificación.
# - Comportamiento general de su distribución.
# - Análisis visual de su posible relación con la depresión.
# - Interpretación de la correlación observada.
#
# ---

# %%
def plot_categoricas(feature):
    fig, axis = plt.subplots(3, figsize = (6, 8), gridspec_kw={"height_ratios": [6, 1, 3]})

    sns.countplot(ax = axis[0], data = df, x = feature)
    axis[0].grid(axis='y', linestyle='--', alpha=0.7)

    sns.heatmap(df[[feature, "ADDEPEV3"]].corr(), annot = True, fmt = ".2f", ax = axis[1], cbar = False)
    sns.countplot(ax = axis[2], data = df, x = feature, hue = "ADDEPEV3")
    axis[2].grid(axis='y', linestyle='--', alpha=0.7)

    plt.tight_layout()
    plt.show()

# %%
def plot_numericas(feature):
    fig, axis = plt.subplots(3, figsize=(6, 8), gridspec_kw={"height_ratios": [6, 1, 3]})

    # Histograma con ticks enteros en el eje x
    sns.histplot(ax=axis[0], data=df, x=feature)
    axis[0].xaxis.set_major_locator(MultipleLocator(1))  # Ticks cada 1 unidad
    axis[0].grid(axis='y', linestyle='--', alpha=0.7)

    # Boxplot con ticks enteros en el eje x
    sns.boxplot(ax=axis[1], data=df, x=feature)
    axis[1].xaxis.set_major_locator(MultipleLocator(1))

    # Heatmap de correlación
    sns.heatmap(df[[feature, "ADDEPEV3"]].corr(), annot=True, fmt=".2f", ax=axis[2], cbar=False)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 🔎 HHADULT – Número de adultos en el hogar
#
# 📂 Tipo de variable: **Numérica**
#
# 🧾 **Descripción**:
# Indica cuántas personas de 18 años o más viven en el hogar del encuestado, incluyendo al propio encuestado. Esta variable puede reflejar el entorno familiar o social cercano.
#
# 🔢 **Rango de valores**:
# - De **0 a 20** adultos por hogar
# - Valores extremos poco frecuentes, pero posibles

# %%
plot_numericas("HHADULT")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los hogares tiene entre **1 y 3 adultos**, siendo el valor más común el **2**.
# - A partir de 4 adultos, la frecuencia disminuye rápidamente, y los valores superiores a 6 son casos muy poco frecuentes.
# - Se observan varios valores atípicos (outliers) por encima de 10 adultos, como se refleja en el boxplot.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - No se visualiza una diferencia clara en los niveles de depresión según el número de adultos en el hogar.
# - La distribución de `ADDEPEV3` parece mantenerse similar independientemente del valor de `HHADULT`, lo que sugiere una relación débil o nula a simple vista.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `-0.04`
# - Se trata de una correlación negativa muy débil. Aunque estadísticamente despreciable, podría apuntar (si acaso) a una mínima tendencia a menor depresión en hogares con más adultos, posiblemente por mayor apoyo social, pero sin evidencia visual ni numérica fuerte que lo respalde.
#
# ---

# %% [markdown]
# ## 🔎 SEXVAR – Sexo del encuestado
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica el sexo de la persona que respondió la encuesta. Esta variable es útil para identificar posibles diferencias de género en los indicadores de salud mental.
#
# 🔢 **Codificación**:
# - 0: Hombre
# - 1: Mujer

# %%
plot_categoricas("SEXVAR")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La muestra está **equilibrada entre hombres y mujeres**, con cantidades casi idénticas en ambas categorías.
# - Esto permite comparaciones de género sin sesgo de representación en el análisis.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - Se observa una **mayor proporción de depresión diagnosticada entre mujeres (1)** en comparación con los hombres (0).
# - Aunque ambos sexos presentan casos de depresión, la diferencia visual es clara: las mujeres reportan un número absoluto mayor de diagnósticos.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.16`
# - La correlación es **positiva y débil**, pero mayor que en muchas otras variables. Esto sugiere una **ligera tendencia** a una mayor prevalencia de diagnóstico de depresión entre mujeres, en línea con hallazgos de salud pública previos.
#
# ---

# %% [markdown]
# ## 🔎 MEDCOST1 – ¿Necesitó ver a un médico pero no pudo por motivos económicos?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Esta variable indica si en los últimos 12 meses la persona necesitó atención médica pero no pudo acceder a ella por razones económicas. Refleja barreras en el acceso a la salud.
#
# 🔢 **Codificación**:
# - 0: No
# - 1: Sí

# %%
plot_categoricas("MEDCOST1")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La gran mayoría de los encuestados indicó que **no** tuvo problemas económicos para acceder a atención médica (valor 0).
# - Solo una minoría (valor 1) reportó que **sí necesitó ver a un médico pero no pudo por razones económicas**.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - Entre quienes **no tuvieron barreras económicas** (0), aún se reportan casos de depresión, pero en una proporción menor.
# - En el grupo que **sí enfrentó barreras de costo** (1), la proporción de personas con depresión es visiblemente más alta.
# - Esto sugiere una relación clara entre dificultades de acceso económico a la salud y la presencia de depresión.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.11`
# - La correlación es débil, pero positiva, y consistente con lo observado visualmente: tener problemas para acceder a atención médica parece asociarse con mayor prevalencia de depresión.
#
# ---

# %% [markdown]
# ## 🔎 SLEPTIM1 – Horas promedio de sueño en un periodo de 24 horas
#
# 📂 Tipo de variable: **Numérica**
#
# 🧾 **Descripción**:
# Esta variable indica cuántas horas, en promedio, duerme la persona durante un día. Es un indicador clave del descanso y puede estar relacionado con la salud física y mental.
#
# 🔢 **Rango de valores**:
# - De **1 a 24** horas de sueño diarias
# - Se esperan valores entre **6 y 9 horas** como lo más frecuente, según recomendaciones de salud

# %%
plot_numericas("SLEPTIM1")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados duerme entre **6 y 8 horas**, siendo el **pico más frecuente las 7 horas**.
# - Existen valores atípicos tanto por debajo de 4 horas como por encima de 10, incluyendo algunos casos extremos de hasta 24 horas.
# - El boxplot muestra una distribución **ligeramente sesgada a la derecha**, con más outliers en valores altos.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - No se observa una diferencia visual clara en la distribución del sueño relacionada con la presencia o ausencia de depresión.
# - Aunque es posible que existan patrones más complejos (como insomnio o hipersomnia en casos depresivos), esta gráfica no los refleja de forma evidente.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `-0.04`
# - La correlación es **muy débil y negativa**, lo que sugiere que dormir más horas podría estar mínimamente asociado a menor prevalencia de depresión, pero no hay evidencia contundente.
#
# ---

# %% [markdown]
# ## 🔎 CVDSTRK3 – ¿Alguna vez le han dicho que tuvo un derrame cerebral?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Esta variable indica si alguna vez un médico o profesional de la salud ha informado al encuestado que ha sufrido un accidente cerebrovascular (stroke). Es un importante indicador de antecedentes de salud neurológica.
#
# 🔢 **Codificación**:
# - 0: No
# - 1: Sí

# %%
plot_categoricas("CVDSTRK3")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados reportó **no haber sufrido un accidente cerebrovascular** (valor 0).
# - Solo una pequeña proporción indicó haber tenido un derrame cerebral (valor 1), lo cual es esperable dada la prevalencia poblacional.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - En ambos grupos (`CVDSTRK3` = 0 y 1) se observan casos de depresión, pero la proporción de personas con diagnóstico de depresión es **visiblemente mayor** entre quienes han tenido un derrame cerebral.
# - Esto sugiere una posible relación entre eventos cerebrovasculares previos y mayor vulnerabilidad a trastornos de salud mental.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.06`
# - Aunque débil, la correlación positiva es coherente con lo observado visualmente: haber sufrido un derrame cerebral se asocia con mayor frecuencia de depresión, probablemente por efectos secundarios neurológicos o emocionales del evento.
#
# ---

# %% [markdown]
# ## 🎯 ADDEPEV3 – Diagnóstico de trastorno depresivo
#
# 📂 Tipo de variable: **Categórica (objetivo)**
#
# 🧾 **Descripción**:
# Indica si el encuestado ha sido diagnosticado alguna vez con un trastorno depresivo, incluyendo depresión mayor, distimia o depresión menor, según evaluación de un profesional de la salud.
#
# 🔢 **Codificación**:
# - 0: No
# - 1: Sí

# %%
fig, axis = plt.subplots(figsize = (6, 4))

sns.countplot(data = df, x = "ADDEPEV3")
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - Aproximadamente **el 20-25%** de los encuestados reporta haber sido diagnosticado con algún tipo de trastorno depresivo (valor 1).
# - La mayoría (alrededor del **75-80%**) no ha recibido este diagnóstico (valor 0).
# - Este desequilibrio en las clases debe tenerse en cuenta al construir modelos predictivos, ya que puede requerir técnicas de balanceo para evitar sesgo hacia la clase mayoritaria.
#
# ### 📌 Nota:
# - `ADDEPEV3` es la **variable objetivo** del análisis.
# - Todos los análisis de relación se realizarán respecto a esta variable para entender qué factores podrían estar asociados con mayor o menor probabilidad de depresión diagnosticada.
#
# ---

# %% [markdown]
# ## 🔎 DIABETE4 – ¿Alguna vez le han dicho que tiene diabetes?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Esta variable indica si un profesional de la salud ha diagnosticado alguna forma de diabetes al encuestado. Incluye casos confirmados, prediabetes y diabetes gestacional.
#
# 🔢 **Codificación**:
# - 0: No
# - 1: Prediabetes o intolerancia a la glucosa
# - 2: Solo durante el embarazo
# - 3: Diabetes confirmada

# %%
plot_categoricas("DIABETE4")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados indicó **no tener diabetes** (valor 0).
# - Un grupo considerable reporta **diabetes confirmada** (valor 3), y en menor medida aparecen casos de **prediabetes** (valor 1) y **diabetes gestacional** (valor 2).
# - La clase más numerosa, con diferencia, es la de no diabéticos.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - En todos los subgrupos con algún tipo de diagnóstico relacionado con la diabetes (valores 1, 2 y 3), se observa una mayor proporción de personas con depresión en comparación con quienes no tienen diabetes.
# - Especialmente en el grupo con **diabetes confirmada (3)**, el número absoluto de casos de depresión es claramente superior respecto a su proporción en el total de esa categoría.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.08`
# - Aunque la correlación es débil, el valor positivo respalda la observación de que **la presencia de condiciones diabéticas se asocia con una mayor prevalencia de diagnóstico de depresión**, lo cual coincide con hallazgos médicos previos sobre comorbilidades.
#
# ---

# %% [markdown]
# ## 🔎 MARITAL – Estado civil
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica el estado civil actual del encuestado. Esta variable permite explorar posibles asociaciones entre situación conyugal y salud mental.
#
# 🔢 **Codificación**:
# - 0: Casado/a
# - 1: Divorciado/a
# - 2: Viudo/a
# - 3: Separado/a
# - 4: Nunca se ha casado
# - 5: Miembro de una pareja no casada

# %%
plot_categoricas("MARITAL")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados se encuentra **casado/a** (valor 0), seguido por personas **divorciadas (1)** y quienes **nunca se han casado (4)**.
# - Los grupos menos representados son los **separados (3)**, **viudos (2)** y quienes viven en pareja sin estar casados (5).
# - Hay una diversidad notable en las situaciones conyugales reportadas.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - Se observa una mayor proporción de **casos de depresión** en personas **divorciadas, separadas, viudas y nunca casadas**.
# - En contraste, el grupo **casado** muestra una proporción menor de diagnósticos de depresión.
# - Esto sugiere una posible relación entre el estado civil y la salud mental, donde el matrimonio podría estar actuando como factor protector (o reflejo de mayor estabilidad emocional/social).
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.09`
# - Aunque la correlación es débil, apunta a una posible asociación entre ciertas situaciones conyugales (especialmente separación o pérdida) y una mayor prevalencia de depresión.
#
# ---

# %% [markdown]
# ## 🔎 RENTHOM1 – ¿Es propietario o alquila su vivienda?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica la situación habitacional del encuestado, diferenciando entre propiedad, alquiler u otros arreglos. Esta variable puede reflejar estabilidad económica y contexto social.
#
# 🔢 **Codificación**:
# - 0: Propietario/a
# - 1: Inquilino/a (alquiler)
# - 2: Otro tipo de arreglo (vivienda prestada, compartida, etc.)

# %%
plot_categoricas("RENTHOM1")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados reporta ser **propietario/a de su vivienda** (valor 0).
# - Un grupo considerable vive en régimen de **alquiler** (valor 1).
# - Una minoría reporta vivir bajo **otros arreglos habitacionales** (valor 2), como viviendas prestadas, familiares o compartidas.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La proporción de depresión es **más alta entre quienes alquilan o viven bajo otros arreglos** que entre los propietarios.
# - Esto sugiere una posible asociación entre inseguridad habitacional o menor estabilidad económica y mayor prevalencia de trastornos depresivos.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.12`
# - Es una **correlación débil pero positiva**, que respalda visualmente la tendencia observada: la falta de propiedad habitacional podría estar asociada a un mayor riesgo de depresión.
#
# ---

# %% [markdown]
# ## 🔎 VETERAN3 – ¿Ha servido alguna vez en las Fuerzas Armadas de EE. UU.?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica si el encuestado ha servido en servicio activo en las Fuerzas Armadas de los Estados Unidos, incluyendo servicio regular, Guardia Nacional o reservas. Esta variable puede reflejar experiencias vitales intensas con potencial impacto en la salud mental.
#
# 🔢 **Codificación**:
# - 0: No
# - 1: Sí

# %%
plot_categoricas("VETERAN3")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados **no ha servido en las Fuerzas Armadas** (valor 0).
# - Una minoría significativa indica que **sí ha servido en servicio activo** (valor 1).
#
# ### 🧠 Relación con `ADDEPEV3`:
# - En ambos grupos (veteranos y no veteranos) hay casos de depresión, pero **no se observa una diferencia marcada** en proporciones.
# - Visualmente, el grupo de veteranos muestra **una proporción algo menor de depresión** que el grupo de no veteranos, aunque esto podría estar influido por otros factores demográficos.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `-0.03`
# - Correlación **negativa muy débil**, sin evidencia concluyente de una relación directa entre la experiencia militar y la prevalencia de depresión en esta muestra.
#
# ---

# %% [markdown]
# ## 🔎 EMPLOY1 – Estado laboral actual
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica la situación laboral actual del encuestado, diferenciando entre trabajo remunerado, autoempleo, desempleo, retiro y otras situaciones. Esta variable es clave para analizar el contexto socioeconómico y su posible impacto en la salud mental.
#
# 🔢 **Codificación**:
# - 0: Empleado/a con salario
# - 1: Autónomo/a
# - 2: Desempleado/a desde hace un año o más
# - 3: Desempleado/a desde hace menos de un año
# - 4: Labores del hogar
# - 5: Estudiante
# - 6: Jubilado/a
# - 7: No puede trabajar

# %%
plot_categoricas("EMPLOY1")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - Las categorías más frecuentes son **empleados por salario (0)** y **jubilados (6)**.
# - También hay una presencia significativa de **trabajadores autónomos (1)** y personas **que no pueden trabajar (7)**.
# - Grupos como **desempleados** (2 y 3), **estudiantes** (5) y **amas de casa** (4) son menos numerosos.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - Las personas **que no pueden trabajar (7)** y **desempleadas** (especialmente desde hace más de un año, valor 2) presentan **una proporción elevada de diagnósticos de depresión**.
# - En contraste, los **empleados con salario (0)** y **jubilados (6)** muestran proporciones más bajas.
# - Esto sugiere una relación clara entre exclusión del mercado laboral y mayor prevalencia de trastornos depresivos.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.09`
# - Aunque débil, la correlación es positiva y consistente con el análisis visual: ciertas situaciones laborales, en especial la inactividad involuntaria, parecen asociarse con mayor riesgo de depresión.
#
# ---

# %% [markdown]
# ## 🔎 DECIDE – ¿Tiene dificultades serias para concentrarse, recordar o tomar decisiones?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica si el encuestado tiene, debido a una condición física, mental o emocional, serias dificultades para concentrarse, recordar o tomar decisiones. Esta variable puede reflejar afectaciones cognitivas relacionadas directa o indirectamente con la salud mental.
#
# 🔢 **Codificación**:
# - 0: No
# - 1: Sí

# %%
plot_categoricas("DECIDE")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados indicó **no tener dificultades serias** para concentrarse, recordar o tomar decisiones (valor 0).
# - Un grupo más reducido respondió que **sí presenta dificultades cognitivas significativas** (valor 1).
#
# ### 🧠 Relación con `ADDEPEV3`:
# - Se observa una **fuerte asociación visual** entre las dificultades cognitivas (DECIDE = 1) y la presencia de diagnóstico de depresión.
# - La proporción de personas con depresión es **considerablemente mayor** entre quienes reportan este tipo de dificultades.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.33`
# - Es una **correlación positiva moderada**, una de las más altas en el dataset hasta ahora.
# - Refleja una posible relación directa entre síntomas cognitivos y depresión, coherente con lo reportado en estudios clínicos.
#
# ---

# %% [markdown]
# ## 🔎 DIFFALON – ¿Tiene dificultades para hacer gestiones solo/a por razones físicas, mentales o emocionales?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica si el encuestado tiene dificultades para realizar actividades cotidianas por su cuenta, como ir al médico o hacer compras, debido a una condición física, mental o emocional. Esta variable es un posible indicador de limitaciones funcionales asociadas a la salud general y mental.
#
# 🔢 **Codificación**:
# - 0: No
# - 1: Sí

# %%
plot_categoricas("DIFFALON")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La gran mayoría de los encuestados reporta **no tener dificultades** para realizar gestiones solo/a (valor 0).
# - Una minoría indica que **sí tiene dificultades importantes** debido a condiciones físicas, mentales o emocionales (valor 1).
#
# ### 🧠 Relación con `ADDEPEV3`:
# - Se observa una **proporción considerablemente más alta de depresión** entre quienes tienen dificultades para hacer gestiones por su cuenta.
# - Este patrón es visualmente claro y coherente con la idea de que la pérdida de autonomía funcional puede estar asociada a una mayor carga emocional o aislamiento.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.21`
# - Es una **correlación positiva moderada**, que sugiere una relación relevante entre limitaciones funcionales y la presencia de diagnóstico depresivo.
#
# ---

# %% [markdown]
# ## 🔎 COLNCNCR – ¿Se ha hecho algún tipo de prueba para detectar cáncer colorrectal (colonografía virtual, CT colonografía, test de sangre oculta en heces, FIT DNA o Cologuard)?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica si la persona ha realizado alguna prueba de detección para cáncer colorrectal distinta a la colonoscopía tradicional. Esta variable puede reflejar hábitos preventivos y acceso a servicios de salud.
#
# 🔢 **Codificación**:
# - 0: No
# - 1: Sí

# %%
plot_categoricas("COLNCNCR")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayor parte de los encuestados **no ha realizado nunca** este tipo de pruebas para la detección de cáncer colorrectal (valor 0).
# - Una proporción menor (valor 1) sí ha pasado por este tipo de estudios preventivos.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La proporción de personas con depresión es similar entre quienes han realizado pruebas y quienes no, sin diferencias visualmente marcadas.
# - La diferencia en números absolutos entre ambos grupos es consistente con su frecuencia general en la muestra.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.03`
# - La correlación es muy baja, cercana a cero, por lo que **no se evidencia una asociación clara** entre la variable `COLNCNCR` y la presencia de depresión.
#
# ---

# %% [markdown]
# ## 🔎 HIVRISK5 – Conductas de riesgo asociadas a VIH
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica si el encuestado ha tenido en el último año algún comportamiento que implique mayor riesgo de contraer VIH. Incluye uso de drogas inyectables sin prescripción, tratamiento por ITS/ETS, o intercambio de sexo por dinero o drogas.
#
# 🔢 **Codificación**:
# - 0: No
# - 1: Sí

# %%
plot_categoricas("HIVRISK5")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La gran mayoría de los encuestados reporta **no haber tenido comportamientos de riesgo asociados a VIH** (valor 0).
# - Un grupo muy reducido indicó que **sí ha tenido** alguno de estos comportamientos en el último año (valor 1).
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La proporción de personas con depresión es mayor entre quienes reportan conductas de riesgo (valor 1) que entre quienes no las reportan.
# - Esto sugiere que los individuos que han enfrentado este tipo de situaciones pueden presentar mayor vulnerabilidad a la depresión.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.06`
# - La correlación es positiva pero débil, consistente con un pequeño aumento del riesgo de depresión en personas que reportan conductas de riesgo para VIH.
#
# ---

# %% [markdown]
# ## 🔎 COVIDPOS – ¿Alguna vez le han diagnosticado COVID-19?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica si un médico, enfermera u otro profesional de la salud ha informado al encuestado que ha tenido COVID-19. También incluye el resultado positivo por prueba casera. Esta variable es relevante para comprender experiencias de salud que pueden influir en el bienestar emocional.
#
# 🔢 **Codificación**:
# - 0: No
# - 1: Test positivo con prueba casera
# - 2: Sí, diagnóstico por profesional de la salud

# %%
plot_categoricas("COVIDPOS")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados reporta **no haber tenido COVID-19** (valor 0).
# - Un grupo considerable indica que ha recibido **diagnóstico positivo por parte de un profesional de salud** (valor 2).
# - Una proporción menor reporta **haber dado positivo solo en pruebas caseras** (valor 1).
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La proporción de depresión es **ligeramente mayor entre quienes han tenido COVID-19 (tanto profesional como test casero)** que entre quienes nunca lo han tenido.
# - Esto sugiere que la enfermedad podría estar asociada a un pequeño aumento en el riesgo de depresión, pero la diferencia es moderada.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.02`
# - Correlación **positiva y muy débil**, lo que indica que el diagnóstico de COVID-19 solo tiene una asociación muy ligera con la presencia de depresión en este conjunto de datos.
#
# ---

# %% [markdown]
# ## 🔎 LSATISFY – ¿Qué tan satisfecho está en general con su vida?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica el nivel general de satisfacción del encuestado con su propia vida, reflejando su bienestar subjetivo. Esta variable es relevante para comprender el estado emocional y su posible relación con la salud mental.
#
# 🔢 **Codificación**:
# - 0: Muy satisfecho
# - 1: Satisfecho
# - 2: Insatisfecho
# - 3: Muy insatisfecho

# %%
plot_categoricas("LSATISFY")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados se encuentra **muy satisfecha (0)** o **satisfecha (1)** con su vida.
# - Un grupo menor refiere estar **insatisfecho (2)** o **muy insatisfecho (3)**.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La proporción de depresión es notablemente mayor entre las personas que reportan **insatisfacción o mucha insatisfacción**.
# - Por el contrario, entre quienes se sienten muy satisfechos o satisfechos, la proporción de depresión es mucho más baja.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.27`
# - Correlación positiva moderada que respalda la intuición: a mayor insatisfacción con la vida, mayor probabilidad de depresión.
#
# ---

# %% [markdown]
# ## 🔎 EMTSUPRT – ¿Con qué frecuencia recibe el apoyo social y emocional que necesita?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica la frecuencia con la que la persona encuestada siente que recibe el apoyo social y emocional que necesita. Esta variable es clave para comprender la red de apoyo del individuo y su impacto potencial en la salud mental.
#
# 🔢 **Codificación**:
# - 1: Siempre o casi siempre
# - 0: A veces, rara vez o nunca

# %%
plot_categoricas("EMTSUPRT")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados afirma que **siempre o casi siempre recibe el apoyo social y emocional que necesita** (valor 1).
# - Una proporción menor reporta que solo **a veces, raramente o nunca** recibe ese tipo de apoyo (valor 0).
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La proporción de depresión es visiblemente mayor entre quienes **no reciben suficiente apoyo emocional**.
# - Por el contrario, entre quienes tienen un apoyo consistente, la proporción de depresión es más baja.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `-0.18`
# - Correlación negativa y débil, que sugiere que una mayor disponibilidad de apoyo social y emocional se asocia con menor probabilidad de depresión.
#
# ---

# %% [markdown]
# ## 🔎 SDHISOLT – ¿Con qué frecuencia se siente socialmente aislado de los demás?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica la frecuencia con la que la persona se siente socialmente aislada. Esta variable es relevante para comprender la sensación de soledad o desconexión social, un factor que puede influir en la salud mental.
#
# 🔢 **Codificación**:
# - 1: Siempre, Usualmente o A veces
# - 0: Raramente o Nunca

# %%
plot_categoricas("SDHISOLT")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayor parte de los encuestados reporta que **raramente o nunca se siente socialmente aislado** (valor 0).
# - Un grupo menor, pero significativo, indica que **a veces, usualmente o siempre** se siente aislado socialmente (valor 1).
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La proporción de depresión es considerablemente mayor entre quienes **se sienten socialmente aislados**.
# - Por el contrario, entre quienes no se sienten aislados, la proporción de depresión es más baja.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.28`
# - Existe una **asociación positiva moderada**, sugiriendo que la sensación de aislamiento social está relacionada con un mayor riesgo de depresión.
#
# ---

# %% [markdown]
# ## 🔎 SDHEMPLY – ¿En los últimos 12 meses ha perdido el empleo o le han reducido las horas de trabajo?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica si la persona ha experimentado pérdida de empleo o reducción en sus horas laborales en el último año. Esta variable es relevante para comprender el impacto del cambio en la situación laboral sobre la salud mental.
#
# 🔢 **Codificación**:
# - 1: Sí
# - 0: No

# %%
plot_categoricas("SDHEMPLY")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La gran mayoría de los encuestados reporta **no haber perdido su empleo ni reducido sus horas de trabajo** en los últimos 12 meses (valor 0).
# - Una proporción menor indica que **sí ha pasado por esta situación** (valor 1).
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La proporción de depresión es mayor entre quienes **sí han perdido el empleo o han visto reducidas sus horas** en comparación con quienes no han vivido esa situación.
# - Esto sugiere que el impacto laboral puede ser un factor que contribuya al malestar emocional.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.06`
# - La correlación es positiva pero débil, consistente con que la inestabilidad laboral está asociada a una mayor probabilidad de depresión, aunque el efecto es pequeño en este conjunto de datos.
#
# ---

# %% [markdown]
# ## 🔎 SDHFOOD1 – ¿Con qué frecuencia en los últimos 12 meses la comida que compró no duró y no tuvo dinero para comprar más?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Esta variable mide la frecuencia con la que el encuestado ha experimentado inseguridad alimentaria por falta de recursos económicos en el último año. Es un indicador clave del nivel socioeconómico y su posible impacto en la salud mental.
#
# 🔢 **Codificación**:
# - 1: Siempre
# - 2: Usualmente
# - 3: A veces
# - 4: Rara vez
# - 5: Nunca

# %%
plot_categoricas("SDHFOOD1")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La gran mayoría de los encuestados reporta que **nunca** han tenido problemas para que la comida dure hasta poder comprar más (valor 5).
# - Una proporción menor indica que ha enfrentado esta situación con distintas frecuencias: **rara vez (4)**, **a veces (3)**, y muy pocos **usualmente (2)** o **siempre (1)**.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La proporción de depresión es notablemente mayor entre quienes reportan que **a veces, usualmente o siempre** tienen problemas para que la comida dure.
# - Por el contrario, quienes nunca experimentan esta situación muestran una proporción mucho menor de depresión.
# - Esto sugiere que la **inseguridad alimentaria** se asocia a un mayor riesgo de depresión.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `-0.18`
# - La correlación es **negativa y débil**, consistente con que mayor frecuencia de inseguridad alimentaria se asocia a mayor probabilidad de depresión.
#
# ---

# %% [markdown]
# ## 🔎 SDHBILLS – ¿En los últimos 12 meses hubo algún momento en que no pudo pagar la hipoteca, el alquiler o las facturas de servicios?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica si la persona ha tenido dificultades económicas para cubrir pagos esenciales (hipoteca, alquiler o servicios) en el último año. Esta variable es un indicador clave de inestabilidad financiera y puede estar asociada con mayor riesgo de problemas de salud mental.
#
# 🔢 **Codificación**:
# - 1: Sí
# - 0: No

# %%
plot_categoricas("SDHBILLS")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La gran mayoría de los encuestados reporta que **no ha tenido dificultades para pagar la hipoteca, el alquiler o los servicios** en el último año (valor 0).
# - Una proporción menor ha enfrentado **dificultades económicas** para cubrir estos pagos esenciales (valor 1).
#
# ### 🧠 Relación con `ADDEPEV3`:
# - Entre quienes han tenido dificultades para pagar sus facturas, la proporción de depresión es **mayor** que entre quienes no han tenido estas dificultades.
# - Esto es consistente con la idea de que la **inestabilidad económica** puede actuar como un factor estresante que contribuye a la depresión.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.16`
# - Correlación positiva y débil, que sugiere una ligera tendencia a mayor depresión entre personas que han tenido dificultades para pagar sus facturas.
#
# ---

# %% [markdown]
# ## 🔎 SDHUTILS – ¿Durante los últimos 12 meses alguna compañía de electricidad, gas, petróleo o agua le amenazó con cortar el servicio?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Refleja una situación de precariedad económica relacionada con el suministro de servicios esenciales. La amenaza de corte por falta de pago puede indicar dificultades financieras severas y representar un factor de estrés significativo en el hogar.
#
# 🔢 **Codificación**:
# - 1: Sí
# - 0: No

# %%
plot_categoricas("SDHUTILS")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados reporta que **no ha sido amenazada** con cortes de servicios básicos como electricidad, gas o agua (valor 0).
# - Un grupo reducido reporta haber recibido **amenazas de corte** por falta de pago (valor 1), lo cual indica una situación de vulnerabilidad económica.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - Las personas que reportaron amenazas de corte de servicios presentan una **mayor proporción de casos de depresión**.
# - Esto sugiere que la **inseguridad en el acceso a servicios esenciales** podría estar asociada a un mayor riesgo de problemas de salud mental.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.12`
# - Correlación **positiva débil**, pero con sentido lógico: los problemas económicos pueden tener impacto emocional y psicológico.
#
# ---

# %% [markdown]
# ## 🔎 SDHTRNSP – ¿En los últimos 12 meses la falta de transporte confiable le impidió asistir a citas médicas, reuniones, trabajo o conseguir cosas necesarias para la vida diaria?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Evalúa la existencia de **barreras de acceso relacionadas con el transporte**, un determinante social clave. La falta de movilidad puede limitar el acceso a servicios de salud, empleo y recursos básicos, afectando negativamente el bienestar general.
#
# 🔢 **Codificación**:
# - 1: Sí
# - 0: No

# %%
plot_categoricas("SDHTRNSP")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La gran mayoría de los encuestados reporta que **no ha tenido problemas de transporte** que les impidieran acudir a citas médicas, reuniones o actividades esenciales (valor 0).
# - Una **minoría significativa** sí ha experimentado estas barreras de movilidad (valor 1), lo que puede reflejar **desigualdad en el acceso a recursos**.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - Entre quienes reportan **problemas de transporte**, la **proporción de personas con depresión es considerablemente mayor**.
# - Esto indica que la **falta de transporte confiable** podría ser un factor indirecto asociado con el deterioro de la salud mental.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.17`
# - Correlación **positiva débil**, pero consistente: las limitaciones de transporte pueden contribuir al aislamiento y a dificultades para acceder a atención médica o apoyo social.

# %% [markdown]
# ## 🔎 _PHYS14D – ¿Durante los últimos 30 días, cuántos días su salud física no fue buena?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Evalúa la **frecuencia de malestar físico** reciente, ofreciendo una aproximación al estado general de salud física. Es un indicador útil para detectar condiciones crónicas o eventos de salud que limitan el bienestar diario.
#
# 🔢 **Codificación**:
# - 0: 0 días de salud física no buena
# - 1: 1 a 13 días de salud física no buena
# - 2: 14 a 30 días de salud física no buena

# %%
plot_categoricas("_PHYS14D")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayor parte de los encuestados reporta **no haber tenido días de mala salud física** en el último mes (valor 0).
# - Un grupo relevante indica haber experimentado entre **1 y 13 días** (valor 1), y una proporción menor **14 o más días** (valor 2) de malestar físico.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La **proporción de depresión aumenta** a medida que se incrementa la cantidad de días con mala salud física.
# - Este patrón sugiere una posible **asociación entre el malestar físico persistente y la salud mental**.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.24`
# - Correlación **positiva débil a moderada**, con sentido clínico: los problemas físicos pueden impactar directamente en el estado emocional y contribuir a cuadros depresivos.

# %% [markdown]
# ## 🔎 _MENT14D – ¿Durante los últimos 30 días, cuántos días su salud mental no fue buena?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Captura la **frecuencia de malestar psicológico reciente**, como estrés, ansiedad o tristeza, en el último mes. Esta medida ofrece una visión general del estado emocional de la persona y puede ser un indicador de riesgo para condiciones de salud mental más graves.
#
# 🔢 **Codificación**:
# - 0: 0 días de salud mental no buena
# - 1: 1 a 13 días de salud mental no buena
# - 2: 14 a 30 días de salud mental no buena

# %%
plot_categoricas("_MENT14D")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados reporta **no haber tenido días de mala salud mental** en el último mes (valor 0).
# - Un grupo considerable indica haber tenido **entre 1 y 13 días** (valor 1), y una fracción menor reporta **14 o más días** (valor 2) con malestar psicológico.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - A medida que aumentan los días con mala salud mental, también lo hace la **proporción de personas con diagnóstico de depresión**.
# - Esto refuerza la conexión entre **síntomas frecuentes de malestar psicológico y la presencia de depresión clínica**.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.44`
# - Correlación **positiva moderada a fuerte**, altamente coherente con la naturaleza de ambas variables relacionadas con la salud mental.

# %% [markdown]
# ## 🔎 _HLTHPLN – ¿Actualmente tiene algún tipo de seguro médico o cobertura de salud?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica si la persona cuenta con **alguna forma de seguro de salud**, ya sea público o privado. Tener cobertura médica es un factor clave para el acceso oportuno a servicios sanitarios y tratamientos, y suele estar vinculado al nivel socioeconómico.
#
# 🔢 **Codificación**:
# - 1: Sí
# - 0: No

# %%
plot_categoricas("_HLTHPLN")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La **inmensa mayoría** de los encuestados reporta contar con **algún tipo de seguro médico** (valor 1).
# - Solo una **pequeña proporción** carece de cobertura de salud (valor 0), lo cual podría limitar su acceso a servicios sanitarios.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La prevalencia de depresión es **ligeramente mayor entre quienes no tienen seguro médico**, aunque la diferencia es poco marcada.
# - Aun así, la **falta de cobertura sanitaria** puede representar una barrera importante para recibir apoyo psicológico o tratamiento adecuado.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.01`
# - Correlación **muy débil**, pero con posible implicación estructural en términos de acceso a atención en salud mental.

# %% [markdown]
# ## 🔎 _TOTINDA – ¿Durante los últimos 30 días, realizó alguna actividad física o ejercicio fuera de su trabajo habitual?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Mide la participación en **actividad física voluntaria**, como caminar, correr, nadar o practicar deportes. La actividad física regular está asociada con mejores resultados en salud general y mental, y puede actuar como un factor protector frente a la depresión.
#
# 🔢 **Codificación**:
# - 1: Sí
# - 0: No

# %%
plot_categoricas("_TOTINDA")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - Una **mayoría significativa** de los encuestados reporta haber realizado **alguna actividad física o ejercicio** en los últimos 30 días (valor 1).
# - Un grupo menor indica que **no ha hecho ejercicio** en ese período (valor 0), lo que podría asociarse a estilos de vida más sedentarios.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La proporción de depresión es **más alta entre quienes no realizan actividad física**.
# - Esto respalda la idea de que la **actividad física puede tener un efecto protector** frente a síntomas depresivos.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `-0.13`
# - Correlación **negativa débil**, pero con coherencia teórica: mayor actividad física se relaciona con menor probabilidad de depresión.

# %% [markdown]
# ## 🔎 _MICHD – ¿Alguna vez un profesional de salud le ha dicho que tiene enfermedad coronaria o ha tenido un infarto?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Identifica a las personas que han sido diagnosticadas con **enfermedad cardíaca coronaria o infarto de miocardio**. Estas condiciones son factores de riesgo importantes en salud general, y pueden estar vinculadas a un mayor impacto emocional o deterioro en la calidad de vida.
#
# 🔢 **Codificación**:
# - 1: Sí
# - 0: No

# %%
plot_categoricas("_MICHD")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados **no ha sido diagnosticada** con enfermedad coronaria o infarto (valor 0).
# - Una **minoría considerable** sí ha reportado haber tenido alguna de estas condiciones cardíacas (valor 1), lo que representa un grupo con posibles vulnerabilidades en salud.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La proporción de depresión es **mayor entre quienes han tenido enfermedad coronaria o infarto**, en comparación con quienes no.
# - Esto sugiere una posible **asociación entre enfermedad cardiovascular y salud mental**, posiblemente mediada por el impacto en la calidad de vida o la percepción de riesgo vital.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.06`
# - Correlación **positiva muy débil**, pero clínicamente plausible, ya que las enfermedades crónicas pueden tener efectos psicológicos considerables.

# %% [markdown]
# ## 🔎 _ASTHMS1 – Estado actual de asma según autoinforme
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Clasifica a los encuestados según su **historial de asma**, una condición respiratoria crónica que puede afectar la calidad de vida. Distingue entre quienes actualmente tienen asma, quienes la han tenido en el pasado y quienes nunca la han experimentado.
#
# 🔢 **Codificación**:
# - 1: Actualmente tiene asma
# - 2: Tuvo asma en el pasado
# - 3: Nunca ha tenido asma

# %%
plot_categoricas("_ASTHMS1")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados **nunca ha tenido asma** (valor 3).
# - Una proporción menor reporta **asma actual** (valor 1), y una fracción aún menor la ha tenido **solo en el pasado** (valor 2).
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La **proporción de depresión es más alta en quienes actualmente tienen asma**, seguida de quienes la tuvieron anteriormente.
# - Esto sugiere que la **presencia de enfermedades respiratorias crónicas** podría estar relacionada con un mayor riesgo de problemas emocionales o psicológicos.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `-0.15`
# - Correlación **negativa débil**, aunque el sentido clínico se mantiene: quienes no han tenido asma tienden a reportar menos depresión.

# %% [markdown]
# ## 🔎 _DRDXAR2 – ¿Alguna vez un médico le ha diagnosticado algún tipo de artritis?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica si la persona ha recibido un **diagnóstico médico de artritis**, incluyendo osteoartritis, artritis reumatoide u otras formas. Esta condición crónica puede generar dolor, limitación funcional y afectar el bienestar físico y emocional.
#
# 🔢 **Codificación**:
# - 1: Sí
# - 0: No

# %%
plot_categoricas("_DRDXAR2")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La población está dividida: una parte significativa **no ha sido diagnosticada** con artritis (valor 0), mientras que una proporción considerable **sí lo ha sido** (valor 1).
# - Esto refleja la **alta prevalencia de enfermedades articulares crónicas** en la población adulta.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La **proporción de depresión es mayor entre quienes tienen diagnóstico de artritis**, en comparación con quienes no lo tienen.
# - Esto sugiere que el **dolor crónico y la limitación funcional** asociada a la artritis pueden impactar negativamente en la salud mental.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.17`
# - Correlación **positiva débil**, pero clínicamente razonable: las enfermedades crónicas pueden incrementar la vulnerabilidad a trastornos del estado de ánimo.

# %% [markdown]
# ## 🔎 _AGEG5YR – Categoría de edad en intervalos de cinco años
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Clasifica a los encuestados en **grupos etarios quinquenales**, facilitando el análisis de tendencias por edad. En este caso, se incluyen los grupos de edad a partir de los 40 años, lo que permite observar el impacto de la edad media y avanzada en variables de salud.
#
# 🔢 **Codificación**:
# - 5: 40 a 44 años
# - 6: 45 a 49 años
# - 7: 50 a 54 años
# - 8: 55 a 59 años
# - 9: 60 a 64 años
# - 10: 65 a 69 años
# - 11: 70 a 74 años
# - 12: 75 a 79 años

# %%
plot_categoricas("_AGEG5YR")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La muestra está bien distribuida entre los grupos de edad de **40 a 79 años**, con un mayor número de participantes entre los **50 y 64 años** (valores 7 a 9).
# - La proporción disminuye gradualmente en los grupos de mayor edad, especialmente a partir de los **75 años** (valor 12).
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La **proporción de depresión es más alta en los grupos de menor edad** dentro del rango observado.
# - A medida que aumenta la edad, la **prevalencia de depresión disminuye ligeramente**, lo que puede estar asociado a distintos factores de resiliencia o sesgo de supervivencia.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `-0.08`
# - Correlación **negativa débil**, pero coherente con estudios que muestran mayor prevalencia de síntomas depresivos en adultos de mediana edad que en adultos mayores.

# %% [markdown]
# ## 🔎 _BMI5CAT – Clasificación del Índice de Masa Corporal (IMC)
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Agrupa a los encuestados según su **Índice de Masa Corporal (IMC)** en cuatro categorías estándar utilizadas en salud pública. El IMC es un indicador general del estado nutricional y se ha asociado con múltiples riesgos para la salud física y mental.
#
# 🔢 **Codificación**:
# - 0: Bajo peso
# - 1: Peso normal
# - 2: Sobrepeso
# - 3: Obesidad

# %%
plot_categoricas("_BMI5CAT")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados se encuentra en las categorías de **sobrepeso (2)** y **obesidad (3)**.
# - Una proporción menor tiene **peso normal (1)** y solo una fracción muy reducida presenta **bajo peso (0)**.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La **prevalencia de depresión aumenta ligeramente** en las categorías de obesidad y bajo peso.
# - Esto sugiere que tanto el **exceso como la deficiencia de peso corporal** podrían asociarse a un mayor riesgo de problemas de salud mental.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.08`
# - Correlación **positiva débil**, aunque coherente con la literatura que vincula el IMC extremo con mayor probabilidad de depresión.

# %% [markdown]
# ## 🔎 _CHLDCNT – Número de niños en el hogar
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica cuántos **niños viven en el hogar del encuestado**, lo cual puede influir en la carga económica, el estrés familiar y la dinámica del hogar. Es un posible factor de contexto en estudios sobre salud mental, especialmente en adultos con responsabilidades de cuidado.
#
# 🔢 **Codificación**:
# - 0: Ningún niño en el hogar
# - 1: Un niño
# - 2: Dos niños
# - 3: Tres niños
# - 4: Cuatro niños
# - 5: Cinco o más niños

# %%
plot_categoricas("_CHLDCNT")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La **gran mayoría** de los encuestados reporta **no tener niños en el hogar** (valor 0).
# - Las categorías con uno o más niños son progresivamente menos frecuentes, siendo **muy baja** la proporción de hogares con tres o más.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - No se observan diferencias destacables en la prevalencia de depresión según el número de niños en el hogar.
# - Esto sugiere que la **presencia de niños no parece estar directamente asociada** con mayores niveles de depresión en esta muestra.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `-0.01`
# - Correlación **prácticamente nula**, lo que indica que el número de niños en el hogar **no se relaciona significativamente** con la presencia de depresión.

# %% [markdown]
# ## 🔎 _EDUCAG – Nivel educativo alcanzado
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Clasifica a los encuestados según su **nivel máximo de estudios completado**, lo cual se asocia frecuentemente con el acceso a mejores oportunidades laborales, condiciones de vida y recursos para el autocuidado en salud.
#
# 🔢 **Codificación**:
# - 0: No terminó la secundaria
# - 1: Graduado de secundaria
# - 2: Asistió a universidad o escuela técnica
# - 3: Graduado de universidad o escuela técnica

# %%
plot_categoricas("_EDUCAG")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados reporta haber **completado estudios universitarios o técnicos** (valor 3).
# - Las categorías intermedias (valor 1 y 2) también tienen representación significativa, mientras que una **minoría no terminó la secundaria** (valor 0).
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La **proporción de depresión es ligeramente más alta** en los grupos con menor nivel educativo.
# - Esto sugiere una posible relación entre **mayor educación y menor prevalencia de depresión**, aunque no es muy marcada.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `-0.02`
# - Correlación **negativa muy débil**, con una posible tendencia leve a que mayor nivel educativo se asocie a menor riesgo de depresión.

# %% [markdown]
# ## 🔎 _INCOMG1 – Nivel de ingresos anuales del hogar (categorías)
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Agrupa a los encuestados según su **nivel de ingresos anuales**, lo cual es un indicador clave de situación socioeconómica. Este factor puede influir en múltiples aspectos de la salud física y mental, incluyendo el acceso a servicios, el estrés financiero y la calidad de vida.
#
# 🔢 **Codificación**:
# - 0: Menos de $15,000
# - 1: $15,000 a menos de $25,000
# - 2: $25,000 a menos de $35,000
# - 3: $35,000 a menos de $50,000
# - 4: $50,000 a menos de $100,000
# - 5: $100,000 a menos de $200,000
# - 6: $200,000 o más

# %%
plot_categoricas("_INCOMG1")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados se encuentra en las categorías de **ingresos medios**: entre $50,000 y $100,000 (valor 4) y entre $100,000 y $200,000 (valor 5).
# - Los extremos, tanto **ingresos bajos** (valores 0 y 1) como **muy altos** (valor 6), son menos frecuentes.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La **prevalencia de depresión es mayor entre quienes reportan menores ingresos**, especialmente en los niveles 0 a 2.
# - A medida que aumentan los ingresos, se observa una **reducción en los casos de depresión**, lo que sugiere que la **estabilidad financiera puede ser un factor protector**.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `-0.16`
# - Correlación **negativa débil**, pero significativa: a mayor ingreso, **menor probabilidad de depresión**, en línea con evidencias sobre determinantes sociales de la salud.

# %% [markdown]
# ## 🔎 _RFBING6 – ¿Ha practicado consumo excesivo de alcohol en una sola ocasión?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Identifica a las personas que reportan episodios de **consumo excesivo de alcohol** (binge drinking), definido como cinco o más bebidas para hombres, y cuatro o más para mujeres, en una misma ocasión. Este patrón de consumo puede tener efectos negativos tanto en la salud física como en la mental.
#
# 🔢 **Codificación**:
# - 0: No
# - 1: Sí

# %%
plot_categoricas("_RFBING6")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La **gran mayoría** de los encuestados **no reporta consumo excesivo de alcohol** en una sola ocasión (valor 0).
# - Un **grupo menor**, aunque significativo, sí ha practicado binge drinking (valor 1).
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La proporción de personas con depresión es **ligeramente menor** entre quienes reportan binge drinking, aunque la diferencia es **poco relevante**.
# - Esto sugiere que en esta muestra, el **consumo excesivo de alcohol no está claramente asociado con mayor prevalencia de depresión**.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `-0.00`
# - Correlación **nula**, lo que indica **ausencia de relación estadística** entre episodios de binge drinking y depresión en estos datos.

# %% [markdown]
# ## 🔎 _AIDTST4 – ¿Alguna vez se ha realizado una prueba para detectar el VIH?
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Indica si el encuestado **se ha hecho una prueba de detección del VIH** en algún momento. Este comportamiento está relacionado con el acceso a servicios de salud preventiva y puede estar influido por factores de riesgo, educación en salud y percepción personal de vulnerabilidad.
#
# 🔢 **Codificación**:
# - 0: No
# - 1: Sí

# %%
plot_categoricas("_AIDTST4")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - Una mayoría de los encuestados **nunca se ha hecho una prueba de VIH** (valor 0).
# - Sin embargo, una proporción relevante **sí ha sido testeada** al menos una vez (valor 1), reflejando cierto nivel de acceso a servicios de salud preventiva.
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La proporción de personas con depresión es **ligeramente mayor entre quienes se han hecho la prueba del VIH**.
# - Esto podría reflejar una **mayor percepción de riesgo, experiencias previas con la salud o mayor contacto con el sistema sanitario**.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.13`
# - Correlación **positiva débil**, con posible componente conductual: mayor preocupación por la salud podría coincidir con mayor vulnerabilidad emocional.

# %% [markdown]
# ## 🔎 tobacco_use – Consumo acumulativo de productos con nicotina
#
# 📂 Tipo de variable: **Categórica**
#
# 🧾 **Descripción**:
# Variable unificada que mide el **nivel acumulado de exposición a nicotina**, incluyendo el consumo de tabaco tradicional, vapeo u otras formas. Refleja el grado de comportamiento de riesgo relacionado con la salud pulmonar, cardiovascular y mental.
#
# 🔢 **Codificación**:
# - 0: No consume nicotina
# - 1: Consume una forma (tabaco, vapeo o similar)
# - 2: Consume dos formas
# - 3: Consume todas las formas disponibles

# %%
plot_categoricas("tobacco_use")

# %% [markdown]
# ---
#
# ### 📊 Distribución general:
# - La mayoría de los encuestados **no consume ningún producto con nicotina** (valor 0).
# - Un porcentaje más reducido consume **una forma** (valor 1), y muy pocos consumen **dos o más formas** (valores 2 y 3).
#
# ### 🧠 Relación con `ADDEPEV3`:
# - La **prevalencia de depresión es mayor entre quienes consumen** uno o más productos con nicotina.
# - Se observa una **tendencia ascendente**: a mayor nivel de consumo combinado, **mayor proporción de depresión**, lo cual sugiere una posible relación acumulativa entre consumo de nicotina y malestar psicológico.
#
# ### 📐 Correlación:
# - **Valor de correlación**: `0.09`
# - Correlación **positiva débil**, pero con sentido clínico: el consumo de nicotina, especialmente en múltiples formas, podría estar asociado con mayor riesgo de depresión.

# %%
cor_matrix = df.corr()

fig, axis = plt.subplots(figsize = (25, 25))

sns.heatmap(cor_matrix, annot = True, fmt = ".2f")

plt.tight_layout()

plt.show()

# %%
cor_matrix["ADDEPEV3"].sort_values(ascending=False)
# Out:
# ADDEPEV3       1.000000
# _MENT14D       0.444423
# DECIDE         0.331924
# SDHISOLT       0.277542
# LSATISFY       0.265539
# _PHYS14D       0.241288
# DIFFALON       0.210456
# _DRDXAR2       0.168216
# SDHTRNSP       0.166005
# SEXVAR         0.163382
# SDHBILLS       0.156891
# _AIDTST4       0.132821
# SDHUTILS       0.124201
# RENTHOM1       0.122033
# MEDCOST1       0.112640
# tobacco_use    0.094331
# MARITAL        0.093201
# EMPLOY1        0.086469
# _BMI5CAT       0.077092
# DIABETE4       0.076151
# SDHEMPLY       0.062410
# _MICHD         0.058155
# CVDSTRK3       0.057612
# HIVRISK5       0.057611
# COLNCNCR       0.031127
# COVIDPOS       0.020356
# _HLTHPLN       0.008847
# _RFBING6      -0.003499
# _CHLDCNT      -0.007001
# _EDUCAG       -0.022170
# VETERAN3      -0.029908
# HHADULT       -0.035088
# SLEPTIM1      -0.039262
# _AGEG5YR      -0.082090
# _TOTINDA      -0.126961
# _ASTHMS1      -0.148607
# _INCOMG1      -0.161336
# SDHFOOD1      -0.176314
# ...

# %% [markdown]
# ## 🧾 Conclusiones del Análisis Gráfico
#
# ### 🎯 Variable objetivo: `ADDEPEV3`
# Indica si una persona ha sido diagnosticada con depresión por un profesional de salud (1 = sí, 0 = no).
#
# ---
#
# ### 🔍 Principales correlaciones con `ADDEPEV3`
#
# #### 🔺 **Variables con mayor correlación positiva**
# Estas variables aumentan su valor a medida que aumenta la probabilidad de haber sido diagnosticado con depresión:
#
# | Variable        | Descripción                             | Correlación |
# |----------------|-----------------------------------------|-------------|
# | `_MENT14D`      | Días con mal estado mental              | **0.44**    |
# | `DECIDE`        | Dificultad para tomar decisiones        | **0.33**    |
# | `SDHISOLT`      | Sensación de soledad                    | **0.28**    |
# | `LSATISFY`      | Satisfacción vital baja                 | **0.27**    |
# | `_PHYS14D`      | Días con mal estado físico              | **0.24**    |
# | `DIFFALON`      | Dificultad para estar solo              | **0.21**    |
# | `_DRDXAR2`      | Diagnóstico de ansiedad                 | **0.17**    |
#
# Estas variables reflejan un patrón común: el impacto de **factores emocionales, de salud mental y bienestar subjetivo** en la presencia de depresión.
#
# ---
#
# #### 🔻 **Variables con correlación negativa**
# Estas variables tienden a reducirse cuando la depresión está presente, o bien, su aumento se asocia a menor prevalencia de depresión:
#
# | Variable        | Descripción                             | Correlación |
# |----------------|-----------------------------------------|-------------|
# | `EMTSUPRT`      | Apoyo emocional                         | **-0.18**   |
# | `SDHFOOD1`      | Inseguridad alimentaria                 | **-0.18**   |
# | `_INCOMG1`      | Nivel de ingresos                       | **-0.16**   |
# | `_ASTHMS1`      | Diagnóstico de asma                     | **-0.15**   |
# | `_TOTINDA`      | Actividad física total                 | **-0.13**   |
# | `_AGEG5YR`      | Grupos de edad                          | **-0.08**   |
# | `SLEPTIM1`      | Horas de sueño                          | **-0.04**   |
# | `HHADULT`       | Número de adultos en el hogar           | **-0.04**   |
#
# El **mayor apoyo emocional, ingresos y actividad física** parecen estar relacionados con menor riesgo de depresión, aunque con correlaciones moderadas o débiles.
#
# ---
#
# ### 📉 Variables con correlación muy baja o casi nula
#
# - `_RFBING6` (binge drinking): -0.003
# - `_HLTHPLN` (plan de salud): 0.009
# - `COVIDPOS` (diagnóstico de COVID): 0.02
# - `COLNCNCR`, `HIVRISK5`, `CVDSTRK3`: entre 0.03 y 0.06
#
# Estas variables no muestran una relación fuerte con la depresión en este análisis.
#
# ---
#
# ### 🧠 Conclusiones generales
#
# - Las correlaciones más relevantes están relacionadas con la **salud mental, toma de decisiones, bienestar emocional y apoyo social**.
# - Factores físicos y económicos también influyen, pero con menor intensidad.
# - El análisis sugiere que **la dimensión psicosocial es clave** en la comprensión de la depresión en esta muestra.
#
# ---
