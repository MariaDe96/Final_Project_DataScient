# %% [markdown]
# # Explore here

# %%
# Your code here
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/workspaces/Final_Project_DataScient/data/processed/keep_vars')
df
# Out:
#         Unnamed: 0  HHADULT  SEXVAR  PERSDOC3  MEDCOST1  SLEPTIM1  CVDINFR4  \
# 0                0      NaN     2.0       1.0       2.0       8.0       2.0
# 1                1      NaN     2.0       2.0       2.0       6.0       2.0
# 2                2      NaN     2.0       1.0       2.0       5.0       2.0
# 3                3      NaN     2.0       1.0       2.0       7.0       2.0
# 4                4      NaN     2.0       2.0       2.0       9.0       2.0
# ...            ...      ...     ...       ...       ...       ...       ...
# 445127      445127      5.0     2.0       3.0       2.0       6.0       2.0
# 445128      445128      2.0     2.0       2.0       2.0       7.0       2.0
# 445129      445129      1.0     2.0       3.0       1.0       5.0       2.0
# 445130      445130      2.0     1.0       2.0       2.0       5.0       1.0
# 445131      445131      1.0     1.0       3.0       1.0       5.0       2.0
#
# ...

# %%
df.shape
# Out:
# (445132, 46)
